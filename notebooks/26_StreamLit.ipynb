# %% [markdown]
# ## **Class 26: StreamLit Coffee**

# %%
import os
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RepeatedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score
)
from sklearn.inspection import permutation_importance
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ### **1. Data loading**
# **Objective**: Obtain the data from source and get a first glimpse of their properties and presentation

# %%
df_raw = pd.read_csv('../data/raw/coffee.csv')
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1339 non-null   int64
#  1   total_cup_points       1339 non-null   float64
#  2   species                1339 non-null   object
#  3   owner                  1332 non-null   object
#  4   country_of_origin      1338 non-null   object
#  5   farm_name              980 non-null    object
#  6   lot_number             276 non-null    object
#  7   mill                   1021 non-null   object
#  8   ico_number             1180 non-null   object
#  9   company                1130 non-null   object
#  10  altitude               1113 non-null   object
#  11  region                 1280 non-null   object
#  12  producer               1107 non-null   object
#  13  number_of_bags         1339 non-null   int64
#  14  bag_weight             1339 non-null   object
#  15  in_country_partner     1339 non-null   object
#  16  harvest_year           1292 non-null   object
#  17  grading_date           1339 non-null   object
#  18  owner_1                1332 non-null   object
#  19  variety                1113 non-null   object
#  20  processing_method      1169 non-null   object
#  21  aroma                  1339 non-null   float64
#  22  flavor                 1339 non-null   float64
#  23  aftertaste             1339 non-null   float64
#  24  acidity                1339 non-null   float64
#  25  body                   1339 non-null   float64
#  26  balance                1339 non-null   float64
#  27  uniformity             1339 non-null   float64
#  28  clean_cup              1339 non-null   float64
#  29  sweetness              1339 non-null   float64
#  30  cupper_points          1339 non-null   float64
#  31  moisture               1339 non-null   float64
#  32  category_one_defects   1339 non-null   int64
#  33  quakers                1338 non-null   float64
#  34  color                  1069 non-null   object
#  35  category_two_defects   1339 non-null   int64
#  36  expiration             1339 non-null   object
#  37  certification_body     1339 non-null   object
#  38  certification_address  1339 non-null   object
#  39  certification_contact  1339 non-null   object
#  40  unit_of_measurement    1339 non-null   object
#  41  altitude_low_meters    1109 non-null   float64
#  42  altitude_high_meters   1109 non-null   float64
#  43  altitude_mean_meters   1109 non-null   float64
# dtypes: float64(16), int64(4), object(24)
# memory usage: 460.4+ KB

# %%
df_raw.sample(10, random_state=2025)
# Out:
#       Unnamed: 0  total_cup_points  species                         owner  \
# 1089        1089             80.33  Arabica      cqi taiwan icp cqi台灣合作夥伴
# 942          942             81.42  Arabica                  kurt kappeli
# 1241        1241             78.00  Arabica     alejandro garcia palacios
# 1332        1332             80.17  Robusta                 andrew hetzel
# 272          272             83.92  Arabica               alfredo bojalil
# 738          738             82.25  Arabica  consejo salvadoreño del café
# 1106        1106             80.17  Arabica    exportadora atlantic, s.a.
# 1183        1183             79.25  Arabica  marco virgilio ramirez teliz
# 14            14             87.83  Arabica   ethiopia commodity exchange
# 596          596             82.75  Arabica               eileen koyanagi
#
#            country_of_origin           farm_name lot_number  \
# 1089                  Taiwan          tokoffee莊園        NaN
# 942                   Mexico             various        NaN
# 1241                  Mexico    finca la fortuna        NaN
# 1332                   India  sethuraman estates        NaN
# 272                   Mexico     finca sant rosa        NaN
# 738              El Salvador      zapato de mico        NaN
# 1106               Nicaragua         los mesones        NaN
# 1183                  Mexico         el aguacate        NaN
# 14                  Ethiopia               aolme        NaN
# 596   United States (Hawaii)                 NaN        NaN
#
#                                  mill      ico_number  \
# 1089                       tokoffee莊園             NaN
# 942    cafe gourmet de sierra azul sc  0016-2814-0001
# 1241                 finca la fortuna      1506558883
# 1332               sethuraman estates             NaN
# 272   agroindustrias unidas de mexico            2222
# 738                            tuxpal             391
# 1106        planta procesadora sebaco    017-053-0125
# 1183   cafes de naranjal s.a. de c.v.      1104367469
# 14                            c.p.w.e        010/0338
# 596                               NaN        KP010914
#
#                                              company  ...       color  \
# 1089                              blossom valley宸嶧國際  ...       Green
# 942                                    globus coffee  ...       Green
# 1241  industrializadora de kaffee andes s.a. de c.v.  ...       Green
# 1332                                 cafemakers, llc  ...       Green
# 272                                      ecomtrading  ...         NaN
# 738                     consejo salvadoreño del café  ...       Green
# 1106                        exportadora atlantic s.a  ...         NaN
# 1183                   cafes de naranjal s.a. de c.v  ...       Green
# 14                                               NaN  ...         NaN
# 596                 kona pacific farmers cooperative  ...  Blue-Green
#
#      category_two_defects            expiration  \
# 1089                    0   December 26th, 2014
# 942                     1         May 1st, 2015
# 1241                    7  September 11th, 2013
# 1332                    0       June 20th, 2014
# 272                     2        June 6th, 2013
# 738                     0        July 7th, 2016
# 1106                    2      April 23rd, 2016
# 1183                   10  September 10th, 2013
# 14                      2     August 31st, 2011
# 596                     0    February 5th, 2015
#
#                                certification_body  \
# 1089                 Blossom Valley International
# 942                  Specialty Coffee Association
# 1241                                      AMECAFE
# 1332                 Specialty Coffee Association
# 272                                       AMECAFE
# 738                     Salvadoran Coffee Council
# 1106  Asociación de Cafés Especiales de Nicaragua
# 1183                                      AMECAFE
# 14                    Ethiopia Commodity Exchange
# 596                  Specialty Coffee Association
#
#                          certification_address  \
# 1089  fc45352eee499d8470cf94c9827922fb745bf815
# 942   36d0d00a3724338ba7937c52a378d085f2172daa
# 1241  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 1332  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 272   59e396ad6e22a1c22b248f958e1da2bd8af85272
# 738   3d4987e3b91399dbb3938b5bdf53893b6ef45be1
# 1106  fc561dd3c2eee024b032933e0a97b4aede0dc206
# 1183  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 14    a176532400aebdc345cf3d870f84ed3ecab6249e
# 596   36d0d00a3724338ba7937c52a378d085f2172daa
#
#                          certification_contact unit_of_measurement  \
# 1089  de73fc9412358b523d3a641501e542f31d2668b0                   m
# 942   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 1241  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 1332  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 272   0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 738   27b21e368fb8291cbea02c60623fe6c98f84524d                   m
# 1106  f79a8d4dee92a80ff14025f03ea34fa316b2132f                   m
# 1183  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 14    61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 596   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                  ft
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters
# 1089               600.0                600.0                600.0
# 942               1550.0               1550.0               1550.0
# 1241               850.0                850.0                850.0
# 1332               750.0                750.0                750.0
# 272               1500.0               1500.0               1500.0
# 738               1500.0               1500.0               1500.0
# 1106              1100.0               1275.0               1187.5
# 1183              1000.0               1000.0               1000.0
# 14                1570.0               1700.0               1635.0
# 596                  NaN                  NaN                  NaN
#
# [10 rows x 44 columns]

# %% [markdown]
# ### **2. Data preprocessing**
# **Objectives**: Perform the data cleaning, data transformation and data reduction steps to avoid data mistmatching, noisy data or data not wrangled

# %%
df_baking = df_raw.copy()
df_baking = df_baking[['total_cup_points','species','country_of_origin','aroma','flavor','aftertaste','acidity','body','balance','uniformity','clean_cup','sweetness','cupper_points','cupper_points','moisture']]
df_baking.columns = df_baking.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.lower()
df_baking['species'] = df_baking['species'].astype("category")
df_baking['country_of_origin'] = df_baking['country_of_origin'].astype("category")

df_baking = df_baking.loc[df_baking['flavor'] != 0].reset_index(drop=True)

df_baking.info()

#df = df_baking.copy()
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   total_cup_points   1338 non-null   float64
#  1   species            1338 non-null   category
#  2   country_of_origin  1337 non-null   category
#  3   aroma              1338 non-null   float64
#  4   flavor             1338 non-null   float64
#  5   aftertaste         1338 non-null   float64
#  6   acidity            1338 non-null   float64
#  7   body               1338 non-null   float64
#  8   balance            1338 non-null   float64
#  9   uniformity         1338 non-null   float64
#  10  clean_cup          1338 non-null   float64
#  11  sweetness          1338 non-null   float64
#  12  cupper_points      1338 non-null   float64
#  13  cupper_points      1338 non-null   float64
#  14  moisture           1338 non-null   float64
# dtypes: category(2), float64(13)
# memory usage: 140.1 KB

# %% [markdown]
# ### **3. Exploratory Data Analysis**
# **Objective**: Summarize the main characteristics of the dataset using descriptive statistics and data visualization methods

# %%
df_train, df_test = train_test_split(df,test_size=0.2,random_state=2025)
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)
df_train.info()

# %%
display(df_train.describe().T)

# %%
df_train.hist(figsize=(8,8))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_train, diag_kind='kde')
plt.show()

# %%
sns.heatmap(df_train.corr(),vmin=-1,vmax=1,cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# #### Rule 0:
# Assume that there is a linear relation between the independent variables and the dependent variables
#
# #### Rule 1:
# Variables should not be too correlated (More than 0.75 or less than -0.75)
#
# #### Rule 2:
# Residuals of our prediction should have a symetrical distribution
#
# #### Rule 3:
# The Residuals should have a homogeneous dispersion

# %% [markdown]
# ### **4. Machine learning**
# **Objective**: Create a model that learns from data to make predictions and generalize to unseen data, and thus perform tasks without explicit instructions

# %%
X_train = df_train.drop('compressive_strength', axis=1)
y_train = df_train['compressive_strength']
X_test = df_test.drop('compressive_strength', axis=1)
y_test = df_test['compressive_strength']

# %%
num_proc = Pipeline([
    ('scaler', MinMaxScaler())
])
lreg_p = Pipeline([
    ('num_processer', num_proc),
    ('lreg', LinearRegression())
])

# %%
lreg_p.fit(X_train, y_train)

# %%
y_hat = lreg_p.predict(X_test)
print(f'MSE: {mean_squared_error(y_test, y_hat)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_hat))}')
print(f'R2: {r2_score(y_test, y_hat)}')

# %%
plt.scatter(y_test, y_hat)
plt.plot([0,80],[0,80],color='r')
plt.xlabel('real')
plt.ylabel('predicted')
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
resid = y_hat-y_test
plt.scatter(y_hat,resid,c='r')
plt.axhline(0,linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('residuals')
plt.show()

# %%
plt.hist(resid)
plt.show()

# %%
print(f'intercept:{lreg_p['lreg'].intercept_:.2f}') # beta_0
print(f'coeficients:{lreg_p['lreg'].coef_}') # list of beta (beta_1, beta_2, beta_3.....beta_n)

# %% [markdown]
# $-32.89 + 0.000122*Cement + 0.105*Slag + 0.094*Ash -0.1296*Water + .322221218*Super Plasticizer + .0193374230*Coarse Aggregate + .0246217848*Fine Aggregate + .113637320*Age $

# %%
importance = permutation_importance(lreg_p,X_test,y_test,n_repeats=25,random_state=2025)
importance_df = pd.DataFrame(importance.importances.T,columns=X_test.columns)
ax = importance_df.plot.box(vert=False)
ax.axvline(x=0,color='k',linestyle='--')
ax.set_title('Permutation Importance (Test Set)')
ax.grid(True)
plt.show()

# %%
#Lasso
cv = RepeatedKFold(n_splits=15,n_repeats=5,random_state=2025)
lreg_lasso = LassoCV(alphas=np.arange(0,1,0.01),cv=cv)
lreg_lasso.fit(X_train,y_train)

# %%
lreg_lasso.alpha_

# %%
#Ridge
cv = RepeatedKFold(n_splits=15,n_repeats=5,random_state=2025)
lreg_ridge = RidgeCV(alphas=np.arange(0,1,0.01),cv=cv)
lreg_ridge.fit(X_train,y_train)

# %%
lreg_ridge.alpha_

# %%
num_proc = Pipeline([
    ('scaler', MinMaxScaler())
])
lreg_ridge_p = Pipeline([
    ('num_processer', num_proc),
    ('lreg_ridge', Ridge(alpha=0.99))
])

# %%
lreg_ridge_p.fit(X_train, y_train)

# %%
y_hat = lreg_ridge_p.predict(X_test)
print(f'MSE: {mean_squared_error(y_test, y_hat)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_hat))}')
print(f'R2: {r2_score(y_test, y_hat)}')

# %%
importance = permutation_importance(lreg_ridge_p,X_test,y_test,n_repeats=25,random_state=2025)
importance_df = pd.DataFrame(importance.importances.T,columns=X_test.columns)
ax = importance_df.plot.box(vert=False)
ax.axvline(x=0,color='k',linestyle='--')
ax.set_title('Permutation Importance (Test Set)')
ax.grid(True)
plt.show()
